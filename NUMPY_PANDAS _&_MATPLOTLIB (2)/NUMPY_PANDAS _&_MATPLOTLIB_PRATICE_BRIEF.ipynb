# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'e:\\DSFT5_L1_C4__NUMPY_PANDAS _&_MATPLOTLIB\\SPRINT_4'

# %%
#********************************************************************************************************************************
loan = pd.read_csv('E:\DSFT5_L1_C4__NUMPY_PANDAS _&_MATPLOTLIB\DS1_C4_S4_Loan_Practice.csv')
loan
#********************************************************************************************************************************
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # TASK 1

# %%
d1 = loan[(loan.Education =='Graduate') & (loan.Loan_Status == 'Y')]

# %%
d1
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001002    Male      No          0  Graduate            No
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 4    LP001008    Male      No          0  Graduate            No
# 5    LP001011    Male     Yes          2  Graduate           Yes
# 8    LP001018    Male     Yes          2  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 608  LP002974    Male     Yes          0  Graduate            No
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %% [markdown]
# # TASK 2

# %%
d2 = loan[(loan.Gender =='Female') & (loan.Self_Employed == 'Yes') & (loan.ApplicantIncome > 4000)]
d2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %% [markdown]
# # TASK 3

# %%
d3 = loan[(loan.Dependents == '3+') & (loan.Property_Area =='Rural') & (loan.Loan_Status == 'Y')]
d3
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %%
print('No of employees in this category are :', d3['Loan_ID'].count())
# Out:
# No of employees in this category are : 13

# %% [markdown]
# # TASK 4

# %%
d4 = loan[(loan.LoanAmount > 290) ]

# %%
print('The Average income of previous applicants who applied for more than 290,000$ loan is : ' ,
      (d4['ApplicantIncome'].mean()).round(2))
# Out:
# The Average income of previous applicants who applied for more than 290,000$ loan is :  18166.16

# %% [markdown]
# # TASK 5

# %%
d5 = loan[(loan.Married =='No') & (loan.Self_Employed == 'Yes') & (loan.Loan_Status =='N')]
d5

print('No of Males and Females are:\n',d5['Gender'].value_counts())
# Out:
# No of Males and Females are:
#  Male      9
# Female    5
# Name: Gender, dtype: int64

# %% [markdown]
# # TASK 6

# %%
loan.sort_values(['Property_Area','ApplicantIncome'])
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 216  LP001722    Male     Yes          0  Graduate            No
# 500  LP002603  Female      No          0  Graduate            No
# 188  LP001644    Male     Yes          0  Graduate           Yes
# 418  LP002345    Male     Yes          0  Graduate            No
# 530  LP002717    Male     Yes          0  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 487  LP002547    Male     Yes          1  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 506  LP002624    Male     Yes          0  Graduate            No
# 171  LP001585    Male     Yes         3+  Graduate            No
# 333  LP002101    Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 216              150             1800.0         135               360
# ...

# %% [markdown]
# # TASK 7

# %%
d7=loan[(loan.Married=='Yes') & (loan.Loan_Status=='Y')]
d7
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 6    LP001013   Male     Yes          0  Not Graduate            No
# 8    LP001018   Male     Yes          2      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2               3000                0.0          66               360
# ...

# %%
coappavg = (d7.CoapplicantIncome.mean()).round(2)

# %%
coappavg
# Out:
# 1690.12

# %%
d7i=d7[d7.CoapplicantIncome<coappavg]
d7i
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 604  LP002959  Female     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
d7i['Loan_ID'].count()
# Out:
# 152

# %% [markdown]
# # TASK 8

# %%
d8 = loan[(loan.Education=='Graduate') & (loan.CoapplicantIncome < 15000) & (loan.CoapplicantIncome > 1025)]

# %%
d8.Loan_ID.count()
# Out:
# 238

# %% [markdown]
# # TASK 9

# %%
d9 = loan[(loan.ApplicantIncome<6000) & (loan.LoanAmount>200) & (loan.Loan_Status=='Y')]
d9
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 21   LP001046    Male     Yes          1      Graduate            No
# 159  LP001552    Male     Yes          0      Graduate            No
# 253  LP001843    Male     Yes          1  Not Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 276  LP001903    Male     Yes          0      Graduate            No
# 361  LP002170    Male     Yes          2      Graduate            No
# 381  LP002229    Male      No          0      Graduate            No
# 502  LP002615    Male     Yes          2      Graduate            No
# 505  LP002622    Male     Yes          2      Graduate            No
# 530  LP002717    Male     Yes          0      Graduate            No
# 562  LP002820    Male     Yes          0      Graduate            No
#
# ...

# %%
d9['Gender'].value_counts()
# Out:
# Male      11
# Female     1
# Name: Gender, dtype: int64

# %%
d9.iloc[0::,[0,1]]  # displaying two columns together :
# Out:
#       Loan_ID  Gender
# 5    LP001011    Male
# 21   LP001046    Male
# 159  LP001552    Male
# 253  LP001843    Male
# 255  LP001846  Female
# 276  LP001903    Male
# 361  LP002170    Male
# 381  LP002229    Male
# 502  LP002615    Male
# 505  LP002622    Male
# 530  LP002717    Male
# 562  LP002820    Male

# %%
d9.iloc[0:, 1]
# Out:
# 5        Male
# 21       Male
# 159      Male
# 253      Male
# 255    Female
# 276      Male
# 361      Male
# 381      Male
# 502      Male
# 505      Male
# 530      Male
# 562      Male
# Name: Gender, dtype: object

# %% [markdown]
# # TASK 10

# %%
du = loan[(loan.Property_Area=='Urban')]
dsu = loan[(loan.Property_Area=='Semiurban')]

# %%
d10 = ((du.shape[0] - dsu.shape[0]) / du.shape[0])
d10
# Out:
# -0.15346534653465346

# %% [markdown]
# # TASK 11

# %%
d11 = loan[loan.Loan_Status == 'Y']
d11
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sorti = d11.sort_values('ApplicantIncome',ascending=False)
sorti
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 333  LP002101    Male     Yes          0      Graduate            No
# 171  LP001585    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# 443  LP002422    Male      No          1      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 530  LP002717    Male     Yes          0      Graduate            No
# 418  LP002345    Male     Yes          0      Graduate            No
# 188  LP001644    Male     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 468  LP002502  Female     Yes          2  Not Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # TASK 12

# %%
d12 = loan[(loan.Gender=='Female') & (loan.Dependents=='2')]
d12
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 29   LP001087  Female      No          2      Graduate           Yes
# 82   LP001267  Female     Yes          2      Graduate            No
# 146  LP001516  Female     Yes          2      Graduate            No
# 219  LP001734  Female     Yes          2      Graduate            No
# 251  LP001836  Female      No          2      Graduate            No
# 293  LP001945  Female      No          2      Graduate            No
# 468  LP002502  Female     Yes          2  Not Graduate           Yes
# 516  LP002670  Female     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 29              3750             2083.0         120               360
# 82              1378             1881.0         167               360
# 146            14866                0.0          70               360
# ...

# %%
d12.loc[0::,['Loan_ID','Gender','Dependents','ApplicantIncome','LoanAmount']]
# Out:
#       Loan_ID  Gender Dependents  ApplicantIncome  LoanAmount
# 29   LP001087  Female          2             3750         120
# 82   LP001267  Female          2             1378         167
# 146  LP001516  Female          2            14866          70
# 219  LP001734  Female          2             4283         127
# 251  LP001836  Female          2             3427         138
# 293  LP001945  Female          2             5417         143
# 468  LP002502  Female          2              210          98
# 516  LP002670  Female          2             2031         113

# %% [markdown]
# # TASK 13

# %%
d13 = loan[(loan.Gender=='Female') & (loan.LoanAmount>200)]

# %%
d13['Loan_Amount_Term'] = 180
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9840\366243179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d13['Loan_Amount_Term']=180

# %%
d13
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 119  LP001422  Female      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 210  LP001708  Female      No          0      Graduate            No
# 233  LP001776  Female      No          0      Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 600  LP002949  Female      No         3+      Graduate           Yes
# 604  LP002959  Female     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 54             11500                0.0         286               180
# ...

# %% [markdown]
# # TASK 14

# %%
d14 = loan

# %%
d14 = d14.rename(columns={'Loan_Amount_Term':'LoanAmountTerm'})

# %%
d14.loc[(d14.LoanAmountTerm == 12) | (d14.LoanAmountTerm == 36),'LoanAmountTerm'] = 60

# %%
d14.shape
# Out:
# (614, 13)

# %% [markdown]
# # TASK 15

# %%
d15 = loan[(loan.Education=='Graduate') & (loan.Self_Employed=='Yes') & (loan.ApplicantIncome>10000)]

# %%
d15.insert(13,'credit',np.nan)

# %%
d15['credit'] = d15.ApplicantIncome*2
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9840\675000155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d15['credit'] = d15.ApplicantIncome*2

# %%
d15 = d15.drop(['credit'],axis=1) # dropping row from dataset
d15
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 128  LP001451    Male     Yes          1  Graduate           Yes
# 130  LP001469    Male      No          0  Graduate           Yes
# 185  LP001640    Male     Yes          0  Graduate           Yes
# 199  LP001673    Male      No          0  Graduate           Yes
# 254  LP001844    Male      No          0  Graduate           Yes
# 370  LP002194  Female      No          0  Graduate           Yes
# 432  LP002386    Male      No          0  Graduate           Yes
# 438  LP002403    Male      No          0  Graduate           Yes
# 475  LP002527    Male     Yes          2  Graduate           Yes
# 478  LP002531    Male     Yes          1  Graduate           Yes
# 525  LP002699    Male     Yes          2  Graduate           Yes
# 557  LP002795    Male     Yes         3+  Graduate           Yes
# ...

# %% [markdown]
# # TASK 16

# %%
d16 = loan[(loan.Dependents=='3+') & (loan.Credit_History==0.0) & (loan.Education=='Not Graduate')]
d16
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
# 466  LP002500    Male     Yes         3+  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 73              4755                0.0          95               342
# 338             1830                0.0         146               360
# 466             2947             1664.0          70               180
#
#      Credit_History Property_Area Loan_Status
# 73                0     Semiurban           N
# 338               0         Urban           N
# 466               0         Urban           N

# %%
loan = loan.drop([73,338,466],axis=0)
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # TASK 17

# %%
d17=loan[(loan.Education=='Graduate')]
d17
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001002    Male      No          0  Graduate            No
# 1    LP001003    Male     Yes          1  Graduate            No
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 4    LP001008    Male      No          0  Graduate            No
# 5    LP001011    Male     Yes          2  Graduate           Yes
# ..        ...     ...     ...        ...       ...           ...
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
d17g = d17.ApplicantIncome.sum()
d17g
# Out:
# 2811568

# %%
d17ng = loan[(loan.Education=='Not Graduate')]
d17ng
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 6    LP001013   Male     Yes          0  Not Graduate            No
# 16   LP001034   Male      No          1  Not Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 20   LP001043   Male     Yes          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 595  LP002940   Male      No          0  Not Graduate            No
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 601  LP002950   Male     Yes          0  Not Graduate           Yes
# 605  LP002960   Male     Yes          0  Not Graduate            No
# 607  LP002964   Male     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 3               2583             2358.0         120               360
# ...

# %%
d17ngi = d17ng.ApplicantIncome.sum()
d17ngi
# Out:
# 496624

# %%
print('The Difference between Graduate And Not Graduate incomes is :' , round(((d17g-d17ngi)/d17ngi)*100,2) , '%')
# Out:
# The Difference between Graduate And Not Graduate incomes is : 466.14 %
