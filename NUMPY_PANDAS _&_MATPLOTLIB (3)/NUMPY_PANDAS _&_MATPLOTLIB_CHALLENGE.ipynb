# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('E:\\car_prices.csv')
data = pd.DataFrame(df)
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %% [markdown]
# # TASK 1

# %%
d1 = data[(data.year==2014)]
d1
# Out:
#         year       make                model                       trim  \
# 2       2014        BMW             3 Series                 328i SULEV
# 4       2014        BMW  6 Series Gran Coupe                       650i
# 6       2014        BMW                   M5                       Base
# 7       2014  Chevrolet                Cruze                        1LT
# 8       2014       Audi                   A4  2.0T Premium Plus quattro
# ...      ...        ...                  ...                        ...
# 558814  2014      Dodge              Charger                         SE
# 558820  2014      Dodge              Charger                         SE
# 558826  2014       Jeep       Grand Cherokee                    Limited
# 558827  2014       Jeep       Grand Cherokee                     Laredo
# 558836  2014       Ford                F-150                        XLT
#
#              body transmission                vin state  condition  odometer  \
# ...

# %%
d11 = d1.sort_values('sellingprice',ascending=True).head()
d11
# Out:
#         year      make         model      trim          body transmission  \
# 293223  2014      Ford  E-Series Van     E-250  E-Series Van    automatic
# 185680  2014  Chrysler           200        LX         Sedan    automatic
# 405960  2014      Ford        Escape  Titanium           SUV    automatic
# 174198  2014    Nissan         Versa    1.6 SV         Sedan    automatic
# 174145  2014   Hyundai    Elantra GT      Base     Hatchback    automatic
#
#                       vin state  condition  odometer  color interior  \
# 293223  1ftne2ew6eda13643    tx        4.1   31886.0  white     gray
# 185680  1c3ccbab7en125253    ca        1.0   16973.0  white    black
# 405960  1fmcu9j94eua96505    nj        4.4   20074.0    red    black
# 174198  3n1cn7ap1el855595    il        1.9   15091.0   gray    black
# 174145  kmhd35lh9eu165404    in        2.0       1.0    red    black
#
#                                                    seller    mmr  \
# ...

# %% [markdown]
# # TASK 2

# %%
d2 = data[(data.year==2010)&(data.make=='BMW')&(data.condition>4.5)]
d2
# Out:
#         year make                  model          trim         body  \
# 43927   2010  BMW               3 Series          328i        Coupe
# 70751   2010  BMW               3 Series          328i        Sedan
# 114558  2010  BMW               6 Series          650i  Convertible
# 114559  2010  BMW               3 Series   328i xDrive        Sedan
# 126368  2010  BMW                     M3          Base        Coupe
# 135141  2010  BMW                     X5     xDrive35d          SUV
# 153657  2010  BMW               3 Series          335d        Sedan
# 153661  2010  BMW               7 Series   750i xDrive        Sedan
# 194514  2010  BMW               5 Series          535i        Sedan
# 226562  2010  BMW               7 Series         750Li        Sedan
# 251236  2010  BMW               3 Series          328i  Convertible
# 251237  2010  BMW                     X3     xDrive30i          SUV
# 258240  2010  BMW               5 Series          528i        Sedan
# ...

# %%
d22 = d2.sellingprice.mean()
d22
# Out:
# 23572.222222222223

# %%
d33 = data[(data.year==2015)&(data.make=='BMW')&(data.condition>4.5)]
d33
# Out:
#         year make     model       trim   body transmission                vin  \
# 7876    2015  BMW        M4       Base  Coupe    automatic  wbs3r9c53fk329392
# 43585   2015  BMW        X1  xDrive28i    SUV    automatic  wbavl1c56fvy26418
# 56898   2015  BMW        X1  xDrive28i    SUV    automatic  wbavl1c56fvy24992
# 56900   2015  BMW        X1  xDrive35i    SUV    automatic  wbavm5c51fvv93813
# 56902   2015  BMW        X1  xDrive35i    SUV    automatic  wbavm5c59fvv94093
# ...      ...  ...       ...        ...    ...          ...                ...
# 548650  2015  BMW        X5  xDrive50i    suv    automatic  5uxkr6c53f0j76217
# 548652  2015  BMW  2 Series      M235i  coupe       manual  wba1j7c57fv288951
# 549682  2015  BMW  3 Series       320i  sedan    automatic  wba3b1c51fk136801
# 549683  2015  BMW  3 Series       328i  sedan    automatic  wba3a5c56ff606212
# 557843  2015  BMW        M4       Base  coupe    automatic  wbs3r9c52fk329996
#
# ...

# %%
d44 = d33.sellingprice.mean()
d44
# Out:
# 42994.68599033816

# %%
print(d22)
print(d44)
# Out:
# 23572.222222222223
# 42994.68599033816

# %%
#diference
dx = (d44-d22)/d22*100
dx
# Out:
# 82.39555687628727

# %% [markdown]
# # TASK 3

# %%
dd3 = data[(data.mmr)&(data.color=='black')]
dd3
# Out:
#         year        make     model         trim       body transmission  \
# 369     2013       Mazda    Mazda2        Sport  Hatchback    automatic
# 381     2013         Kia       Rio           LX      Sedan    automatic
# 457     2013         Kia     Forte           LX      Sedan    automatic
# 940     2012       Dodge   Avenger           SE      Sedan    automatic
# 952     2012   Chevrolet    Malibu     LS Fleet      Sedan    automatic
# ...      ...         ...       ...          ...        ...          ...
# 558644  2004       Volvo      XC90         2.5T        suv          NaN
# 558684  2011         Kia    Sedona           LX    minivan    automatic
# 558710  2006  Volkswagen       GTI         Base  hatchback    automatic
# 558754  2006         BMW  7 Series        750Li      sedan    automatic
# 558795  2006    Cadillac       DTS  Performance      Sedan    automatic
#
#                       vin state  condition  odometer  color interior  \
# ...

# %%
dd4 = data[(data.mmr)&(data.color=='gray')]
dd4
# Out:
#         year       make         model        trim       body transmission  \
# 201     2013    Hyundai        Accent         GLS      Sedan    automatic
# 425     2013        Kia         Forte          EX      Sedan    automatic
# 662     2013     Toyota         Yaris           L  Hatchback    automatic
# 723     2013     Nissan         Versa  1.6 S Plus      Sedan    automatic
# 937     2012      Dodge       Avenger          SE      Sedan    automatic
# ...      ...        ...           ...         ...        ...          ...
# 558611  2007        BMW      5 Series       530xi      sedan          NaN
# 558633  2006      Mazda        Mazda3           s  hatchback          NaN
# 558641  2004      Honda        Accord          EX      sedan    automatic
# 558792  2011  Chevrolet           HHR          LT      Wagon    automatic
# 558803  2007       Ford  Five Hundred         SEL      sedan    automatic
#
#                       vin state  condition  odometer color interior  \
# ...

# %%
m1 = dd3.mean()
print(m1)
m2 = dd4.mean()
print(m2)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10600\299241281.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   m1 = dd3.mean()
# year              2006.630487
# condition            2.747815
# odometer        113687.559311
# mmr               5633.632341
# sellingprice      5433.762708
# dtype: float64
# year              2007.143471
# condition            2.831445
# odometer        109776.148407
# mmr               5788.337948
# sellingprice      5649.828184
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10600\299241281.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   m2 = dd4.mean()

# %%
diff  =((m2-m1)/m1*100).round(2)
print(diff)

difff = m2 - m1
print(difff.round(2))
# Out:
# year            0.03
# condition       3.04
# odometer       -3.44
# mmr             2.75
# sellingprice    3.98
# dtype: float64
# year               0.51
# condition          0.08
# odometer       -3911.41
# mmr              154.71
# sellingprice     216.07
# dtype: float64

# %%
#the difference is '2.75' percentagewise

# %%
#the exact difference is '154.70'

# %% [markdown]
# # TASK 4

# %%
d4 = data[(data.year==2013) | (data.year==2014) | (data.year==2015)]
d4
# Out:
#         year    make                model        trim       body transmission  \
# 0       2015     Kia              Sorento          LX        SUV    automatic
# 1       2015     Kia              Sorento          LX        SUV    automatic
# 2       2014     BMW             3 Series  328i SULEV      Sedan    automatic
# 3       2015   Volvo                  S60          T5      Sedan    automatic
# 4       2014     BMW  6 Series Gran Coupe        650i      Sedan    automatic
# ...      ...     ...                  ...         ...        ...          ...
# 558826  2014    Jeep       Grand Cherokee     Limited        SUV    automatic
# 558827  2014    Jeep       Grand Cherokee      Laredo        SUV    automatic
# 558832  2015     Kia                 K900      Luxury      Sedan          NaN
# 558835  2015  Nissan               Altima       2.5 S      sedan    automatic
# 558836  2014    Ford                F-150         XLT  SuperCrew    automatic
#
# ...

# %%
d4i = pd.crosstab(d4.make,d4.color, rownames=['make'],colnames=['color'])
d4i
# Out:
# color          beige  black  blue  brown  burgundy  charcoal  gold  gray  \
# make
# Acura              0    170    19      5        20         2     0   107
# Audi               2    402    78     10         1         0     1   181
# BMW               34   1235   252     99         1         1     8   710
# Bentley            0      5     3      0         0         0     0     3
# Buick             21    157    55     25        12         1    19   189
# Cadillac          55    298    36     12         2         0    50    85
# Chevrolet        421   3570  1582    153       167        36   354  2933
# Chrysler         175   1599   848     56       232        18   334  1343
# Dodge            129   2412  1722     15       100        40   311  2304
# FIAT               7    123    37     12         0         9     0    91
# Ford              55   7102  2209    550       444        12    70  5076
# GMC               39    438    91     31        30         5    37   214
# ...

# %% [markdown]
# # TASK 5

# %%
d5 = data[(data.body=='SUV')&(data.saledate=='Fri Dec 19 2014 09:00:00 GMT-0800 (PST)')]
d5
# Out:
#         year       make       model               trim body transmission  \
# 7880    2015  Chevrolet    Suburban                LTZ  SUV          NaN
# 8042    2012     Subaru    Forester  2.5X Premium PZEV  SUV          NaN
# 8108    2012     Toyota  Highlander               Base  SUV          NaN
# 8188    2012     Toyota  Highlander            Limited  SUV          NaN
# 8223    2012     Toyota        RAV4              Sport  SUV    automatic
# ...      ...        ...         ...                ...  ...          ...
# 143774  2011    Hyundai      Tucson            Limited  SUV    automatic
# 175402  2007     Toyota        RAV4            Limited  SUV    automatic
# 254350  2004     Toyota  Highlander               Base  SUV          NaN
# 340196  2002      Honda        CR-V                 EX  SUV       manual
# 344506  2001     Toyota  Highlander                 V6  SUV          NaN
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
pvt5 = pd.pivot_table(d5,index=['body'],values=['sellingprice'],aggfunc='sum')
pvt5
# Out:
#       sellingprice
# body
# SUV       10343000

# %%
d51 = data[(data.body=='SUV')&(data.saledate=='Thu Jan 15 2015 04:30:00 GMT-0800 (PST)')]
d51
# Out:
#         year           make        model       trim body transmission  \
# 906     2012            BMW           X3  xDrive28i  SUV    automatic
# 1002    2012            BMW           X6  xDrive50i  SUV    automatic
# 1420    2012     Land Rover  Range Rover        HSE  SUV    automatic
# 1448    2011     Land Rover  Range Rover        HSE  SUV    automatic
# 2106    2011            BMW           X5  xDrive35d  SUV    automatic
# ...      ...            ...          ...        ...  ...          ...
# 148837  2012  Mercedes-Benz      M-Class   ML63 AMG  SUV    automatic
# 441493  1999         Toyota         RAV4       Base  SUV          NaN
# 502846  2000     Oldsmobile      Bravada       Base  SUV    automatic
# 517488  1999           Ford   Expedition        XLT  SUV    automatic
# 547089  1999           Ford     Explorer         XL  SUV    automatic
#
#                       vin state  condition  odometer  color interior  \
# ...

# %%
pvt51 = pd.pivot_table(d51,index=['body'],values=['sellingprice'],aggfunc='sum')
pvt51
# Out:
#       sellingprice
# body
# SUV        9650725

# %%
print(pvt5)
print(pvt51)
pvtd = pvt5-pvt51
print('diference between the given period : \n',pvtd)
# Out:
#       sellingprice
# body
# SUV       10343000
#       sellingprice
# body
# SUV        9650725
# diference between the given period :
#        sellingprice
# body
# SUV         692275

# %%
c51 = pvtd/pvt5*100
c51
# Out:
#       sellingprice
# body
# SUV       6.693174

# %%
c52 = pvtd/pvt51*100
c52
# Out:
#       sellingprice
# body
# SUV       7.173295

# %%
percentchange = c52-c51
percentchange
print('therefore, the percentage sales difference of SUV between the given period is : \n',percentchange)
# Out:
# therefore, the percentage sales difference of SUV between the given period is :
#        sellingprice
# body
# SUV       0.480121

# %% [markdown]
# # TASK 6

# %%
d6 = df

# %%
d6.insert(16,'Discounted_Price',np.nan)

# %%
d6i = d6[(d6.make=='Ford') | (d6.make=='Chevrolet')]

# %%
d6i['Discounted_Price'] = d6i.sellingprice*0.90
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10600\2030831874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d6i['Discounted_Price'] = d6i.sellingprice*0.90

# %%
d6[(d6.make=='Ford') | (d6.make=='Chevrolet')] = d6i
d6i.head()
# Out:
#     year       make   model trim         body transmission                vin  \
# 7   2014  Chevrolet   Cruze  1LT        Sedan    automatic  1g1pc5sb2e7128460
# 9   2014  Chevrolet  Camaro   LT  Convertible    automatic  2g1fb3d37e9218789
# 12  2015       Ford  Fusion   SE        Sedan    automatic  3fa6p0hdxfr145753
# 14  2014  Chevrolet   Cruze  2LT        Sedan    automatic  1g1pe5sbxe7120097
# 18  2014  Chevrolet  Camaro   LS        Coupe    automatic  2g1fa1e39e9134494
#
#    state  condition  odometer  color interior  \
# 7     ca        2.0   28617.0  black    black
# 9     ca        3.0    4809.0    red    black
# 12    ca        2.0    5559.0  white    beige
# 14    ca        NaN   15686.0   blue    black
# 18    ca        1.7   13441.0  black    black
#
#                                                seller    mmr  sellingprice  \
# 7   enterprise vehicle exchange / tra / rental / t...  11900          9800
# ...

# %%
d6ii = d6[(d6.make != 'Ford') & (d6.make != 'Chevrolet')]
# 20% DISCOUNT NOT FOR FORD AND CHEVROLET!

# %%
d6ii['Discounted_Price'] = d6ii.sellingprice * 0.80
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10600\2796185304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d6ii['Discounted_Price']=d6ii.sellingprice*0.80

# %%
d6[(d6.make != 'Ford') & (d6.make != 'Chevrolet')] = d6ii

# %%
d6ii.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca        4.5    1331.0   gray    black
# 3  yv1612tb4f1310987    ca        4.1   14282.0  white    black
# 4  wba6b2c57ed129731    ca        4.3    2641.0   gray    black
#
#                                    seller    mmr  sellingprice  \
# 0                 kia motors america, inc  20500         21500
# ...

# %% [markdown]
# # TASK 7

# %%
df.isnull().sum()
# Out:
# year                    0
# make                10301
# model               10399
# trim                10651
# body                13195
# transmission        65353
# vin                     4
# state                   1
# condition           11794
# odometer               94
# color                 749
# interior              749
# seller                  0
# mmr                     0
# sellingprice            0
# saledate               25
# Discounted_Price        0
# dtype: int64

# %%
df = df.drop('vin',axis=1)

# %%
df.isnull().sum()
# Out:
# year                    0
# make                10301
# model               10399
# trim                10651
# body                13195
# transmission        65353
# state                   1
# condition           11794
# odometer               94
# color                 749
# interior              749
# seller                  0
# mmr                     0
# sellingprice            0
# saledate               25
# Discounted_Price        0
# dtype: int64

# %%
df['make'] = df['make'].fillna('Ford')

# %%
df['model'] = df['model'].fillna('Altima')

# %%
df.trim = df.trim.fillna('Base')

# %%
df.body = df.body.fillna('Sedan')

# %%
df['transmission'] = df['transmission'].fillna('automatic')

# %%
df['state'] = df['state'].fillna('fl')

# %%
df.condition.mean()
# Out:
# 3.4239932216370828

# %%
df.condition = df.condition.fillna(3.4)

# %%
df.odometer.mean()
# Out:
# 68320.43754821089

# %%
df.odometer = df.odometer.fillna(68320)

# %%
df.color = df.color.fillna('black')

# %%
df.interior = df.interior.fillna('black')

# %%
df.isnull().sum()
# Out:
# year                 0
# make                 0
# model                0
# trim                 0
# body                 0
# transmission         0
# state                0
# condition            0
# odometer             0
# color                0
# interior             0
# seller               0
# mmr                  0
# sellingprice         0
# saledate            25
# Discounted_Price     0
# dtype: int64

# %%
# NO MISSING VALUES LEFT!
