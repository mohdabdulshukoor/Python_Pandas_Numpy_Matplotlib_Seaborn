# %%
import pandas as pd;
import numpy as np;

# %%
data=pd.read_csv('housing.csv')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # TASK 1

# %%
x1=data[(data.LotArea>6000) & (data.LotConfig=='Corner')]
x1.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 3          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7          Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 9          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 14         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 15         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
from sqlalchemy import create_engine

# %%
hostname='localhost'
dbname='C4_challenge'
username='root'
pwd='a10s11q15'

engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host=hostname,db=dbname,user=username,pw=pwd))
x1.to_sql('TASK 1', engine, index=False)

# %% [markdown]
# # TASK 2

# %%
x2=data[(data.LandContour=='Lvl') & (data.HouseStyle=='1Story') & (data.BldgType=='1Fam')]

# %%
x2.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 12  13          20       RL          NaN    12968   Pave   NaN      IR2
# 13  14          20       RL         91.0    10652   Pave   NaN      IR1
#
#    LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 6          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 10         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 12         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 13         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hostname='localhost'
dbname='C4_challenge'
username='root'
pwd='a10s11q15'

engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host=hostname,db=dbname,user=username,pw=pwd))
x1.to_sql('TASK 2', engine, index=False)

# %% [markdown]
# # TASK 3

# %%
x3=data[(data.BldgType=='TwnhsE') | (data.BldgType=='Twnhs')]

# %%
x3.head(5)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 23  24         120       RM         44.0     4224   Pave   NaN      Reg
# 34  35         120       RL         60.0     7313   Pave   NaN      Reg
# 45  46         120       RL         61.0     7658   Pave   NaN      Reg
# 56  57         160       FV         24.0     2645   Pave  Pave      Reg
# 62  63         120       RL         44.0     6442   Pave   NaN      IR1
#
#    LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 23         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 34         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 45         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 56         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 62         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hostname='localhost'
dbname='C4_challenge'
username='root'
pwd='a10s11q15'

engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host=hostname,db=dbname,user=username,pw=pwd))
x1.to_sql('TASK 3', engine, index=False)

# %% [markdown]
# # TASK 4

# %%
x4=data[(data.Exterior1st=='CemntBd') & (data.BsmtCond!='NA') & (data.BedroomAbvGr>3)]

# %%
x4.head()
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 316  317          60       RL         94.0    13005   Pave   NaN      IR1
# 349  350          60       RL         56.0    20431   Pave   NaN      IR2
# 377  378          60       FV        102.0    11143   Pave   NaN      IR1
# 769  770          60       RL         47.0    53504   Pave   NaN      IR2
# 875  876          60       FV         75.0     9000   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 316         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 349         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 377         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769         HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 875         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hostname='localhost'
dbname='C4_challenge'
username='root'
pwd='a10s11q15'

engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host=hostname,db=dbname,user=username,pw=pwd))
x1.to_sql('TASK 4', engine, index=False)

# %% [markdown]
# # TASK 5

# %%
x5=data[(data.GarageCars>=2) & (data.GarageArea>500)]
x5.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
# 6         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      8
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hostname='localhost'
dbname='C4_challenge'
username='root'
pwd='a10s11q15'

engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host=hostname,db=dbname,user=username,pw=pwd))
x1.to_sql('TASK 5', engine, index=False)
