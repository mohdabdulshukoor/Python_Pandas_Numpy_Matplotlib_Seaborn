#  18967.5   31150.    18221.25  29855.625 27895.    18300.625 18636.25
#  29982.5   24933.125 29951.875 29073.75  27671.875 19218.125 31119.375
#  28636.25  23960.625 27521.25  22898.125 25662.5   26606.875 22331.875
#  20205.625 27341.875 18065.    25670.    29432.5   26163.75  18348.125
#  21805.    22886.875 16153.75  27438.75  15863.125 16016.875 28959.375
#  30878.125 17994.375 18218.75  26239.375 27456.875 19644.375 18633.125
#  29686.25  30683.75  17588.75  19142.5   16676.25  23693.75  25166.25
#  23552.5   28522.5   23638.75  30416.875 18346.25  22730.625 30363.125
# ...

# %%
#4
ctc_sales = ctc_hr+5000
print(ctc_sales)
# Out:
# [38020 52268 52009 38964 47521 48312 40870 43214 45055 37396 54085 48233
#  33996 31253 37431 38632 31166 43436 44095 54481 37190 47633 31419 47407
#  35255 30156 37101 47014 43792 36728 33254 46555 44493 30042 32777 35348
#  54840 34154 52769 49632 34281 34818 52972 44893 52923 51518 49275 35749
#  54791 50818 43337 49034 41637 46060 47571 40731 37329 48747 33904 46072
#  52092 46862 34357 39888 41619 30846 48902 30381 30627 51335 54405 33791
#  34150 46983 48931 36431 34813 52498 54094 33142 35628 31682 42910 45266
#  42684 50636 42822 53667 34354 41369 53581 47594 37586 37112 37532 40839
#  36349 49749 30910 39745 48052 40129 34565 41630 54946 54272 30285 43983
#  53076 30846 44467 43465 54306 37069 50060 52846 42812 38112 31519 30911
#  32590 54061 47270 46689 41565 40306 43137 30127 53610 49627 33024 43164
#  34908 43730 42722 44287 38336 46384 44569 46366 43216 50712 42314 32045
#  48618 39094 41932 38876 30257 32872 50684 31630 33051 49837 35329 54830
# ...

# %% [markdown]
# # TASK 3

# %%
avg_hr_sal = np.mean(ctc_hr)
print(avg_hr_sal)

avg_fin_sal = np.mean(ctc_fin)
print(avg_fin_sal)

avg_it_sal = np.mean(ctc_it)
print(avg_it_sal)

avg_sales_sal = np.mean(ctc_sales)
print(avg_sales_sal)

#so the finance department is costing more to the company regarding salary.
# Out:
# 37293.942
# 46617.4275
# 23308.71375
# 42293.942

# %% [markdown]
# # TASK 4

# %%
h_hr = np.sort(ctc_hr[::-1])

print("top 10 salaries in hr dep is : \n",h_hr[0:10])

print("sum of highest hr department salaries : \n",np.sum(h_hr))
# Out:
# top 10 salaries in hr dep is :
#  [25030 25035 25042 25127 25156 25203 25208 25257 25285 25327]
# sum of highest hr department salaries :
#  18646971

# %%
h_fin = np.sort(ctc_fin[::-1])

print("top 10 salaries in fin dep is : \n",h_fin[0:10])

print("sum of highest finance department salaries :\n",np.sum(h_fin))
# Out:
# top 10 salaries in fin dep is :
#  [31287.5  31293.75 31302.5  31408.75 31445.   31503.75 31510.   31571.25
#  31606.25 31658.75]
# sum of highest finance department salaries :
#  23308713.75

# %%
h_it = np.sort(ctc_it[::-1])

print("top 10 salaries in it dep is : \n",h_it[0:10])

print("sum of highest it department salaries :\n",np.sum(h_it))
# Out:
# top 10 salaries in it dep is :
#  [15643.75  15646.875 15651.25  15704.375 15722.5   15751.875 15755.
#  15785.625 15803.125 15829.375]
# sum of highest it department salaries :
#  11654356.875

# %%
h_sales = np.sort(ctc_sales[::-1])

print("top TEN salaries in sales dep is : \n",h_sales[:10])

print("sum of highest sales department salaries :\n",np.sum(h_sales))
# Out:
# top TEN salaries in sales dep is :
#  [30030 30035 30042 30127 30156 30203 30208 30257 30285 30327]
# sum of highest sales department salaries :
#  21146971

# %% [markdown]
# # TASK 5

# %%
ctc_hr1 = np.count_nonzero(ctc_hr[ctc_hr>45000])
print(ctc_hr1)

ctc_fin1 = np.count_nonzero(ctc_fin[ctc_fin>45000])
print(ctc_fin1)

ctc_it1 = np.count_nonzero(ctc_it[ctc_it>45000])
print(ctc_it1)

ctc_sales1 = np.count_nonzero(ctc_sales[ctc_sales>45000])
print(ctc_sales1)


total_employees = ctc_hr1 + ctc_fin1 + ctc_it1 + ctc_sales1
print("sum of total employees :",total_employees)
# Out:
# 97
# 272
# 0
# 198
# sum of total employees : 567

# %% [markdown]
# # TASK 6

# %%
upd_sal = np.where(ctc_sales <= 20000,ctc_sales*1.20,ctc_sales)
print(upd_sal)
# Out:
# [38020. 52268. 52009. 38964. 47521. 48312. 40870. 43214. 45055. 37396.
#  54085. 48233. 33996. 31253. 37431. 38632. 31166. 43436. 44095. 54481.
#  37190. 47633. 31419. 47407. 35255. 30156. 37101. 47014. 43792. 36728.
#  33254. 46555. 44493. 30042. 32777. 35348. 54840. 34154. 52769. 49632.
#  34281. 34818. 52972. 44893. 52923. 51518. 49275. 35749. 54791. 50818.
#  43337. 49034. 41637. 46060. 47571. 40731. 37329. 48747. 33904. 46072.
#  52092. 46862. 34357. 39888. 41619. 30846. 48902. 30381. 30627. 51335.
#  54405. 33791. 34150. 46983. 48931. 36431. 34813. 52498. 54094. 33142.
#  35628. 31682. 42910. 45266. 42684. 50636. 42822. 53667. 34354. 41369.
#  53581. 47594. 37586. 37112. 37532. 40839. 36349. 49749. 30910. 39745.
#  48052. 40129. 34565. 41630. 54946. 54272. 30285. 43983. 53076. 30846.
#  44467. 43465. 54306. 37069. 50060. 52846. 42812. 38112. 31519. 30911.
#  32590. 54061. 47270. 46689. 41565. 40306. 43137. 30127. 53610. 49627.
# ...

# %% [markdown]
# # TASK 7

# %%
#print(ctc_sales)

#finding the positions 
post1996 = np.where(sales == 1996)
post1997 = np.where(sales == 1997)
post1998 = np.where(sales == 1998)
post1999 = np.where(sales == 1999)
post2000 = np.where(sales == 2000)

print(post1996)
print(post1997)
print(post1998)
print(post1999)
print(post2000)

#deleting 5 employees
sales = np.delete(sales,(495,496,497,498,499))
print(sales)
# Out:
# (array([495], dtype=int64),)
# (array([496], dtype=int64),)
# (array([497], dtype=int64),)
# (array([498], dtype=int64),)
# (array([499], dtype=int64),)
# [1501 1502 1503 1504 1505 1506 1507 1508 1509 1510 1511 1512 1513 1514
#  1515 1516 1517 1518 1519 1520 1521 1522 1523 1524 1525 1526 1527 1528
#  1529 1530 1531 1532 1533 1534 1535 1536 1537 1538 1539 1540 1541 1542
#  1543 1544 1545 1546 1547 1548 1549 1550 1551 1552 1553 1554 1555 1556
#  1557 1558 1559 1560 1561 1562 1563 1564 1565 1566 1567 1568 1569 1570
#  1571 1572 1573 1574 1575 1576 1577 1578 1579 1580 1581 1582 1583 1584
#  1585 1586 1587 1588 1589 1590 1591 1592 1593 1594 1595 1596 1597 1598
#  1599 1600 1601 1602 1603 1604 1605 1606 1607 1608 1609 1610 1611 1612
#  1613 1614 1615 1616 1617 1618 1619 1620 1621 1622 1623 1624 1625 1626
#  1627 1628 1629 1630 1631 1632 1633 1634 1635 1636 1637 1638 1639 1640
#  1641 1642 1643 1644 1645 1646 1647 1648 1649 1650 1651 1652 1653 1654
# ...

# %%
#adding 5 new employees
new_emp = np.arange(2001,2006)
print(new_emp)
# Out:
# [2001 2002 2003 2004 2005]

# %%
sales = np.append(sales,new_emp)
print(sales)
# Out:
# [1501 1502 1503 1504 1505 1506 1507 1508 1509 1510 1511 1512 1513 1514
#  1515 1516 1517 1518 1519 1520 1521 1522 1523 1524 1525 1526 1527 1528
#  1529 1530 1531 1532 1533 1534 1535 1536 1537 1538 1539 1540 1541 1542
#  1543 1544 1545 1546 1547 1548 1549 1550 1551 1552 1553 1554 1555 1556
#  1557 1558 1559 1560 1561 1562 1563 1564 1565 1566 1567 1568 1569 1570
#  1571 1572 1573 1574 1575 1576 1577 1578 1579 1580 1581 1582 1583 1584
#  1585 1586 1587 1588 1589 1590 1591 1592 1593 1594 1595 1596 1597 1598
#  1599 1600 1601 1602 1603 1604 1605 1606 1607 1608 1609 1610 1611 1612
#  1613 1614 1615 1616 1617 1618 1619 1620 1621 1622 1623 1624 1625 1626
#  1627 1628 1629 1630 1631 1632 1633 1634 1635 1636 1637 1638 1639 1640
#  1641 1642 1643 1644 1645 1646 1647 1648 1649 1650 1651 1652 1653 1654
#  1655 1656 1657 1658 1659 1660 1661 1662 1663 1664 1665 1666 1667 1668
#  1669 1670 1671 1672 1673 1674 1675 1676 1677 1678 1679 1680 1681 1682
# ...

# %% [markdown]
# # TASK 8

# %%
s_hr = np.sum(hr)
print(s_hr)

s_sales = np.sum(sales)
print(s_sales)

avg_hr = np.mean(ctc_hr)
avg_sales = np.mean(ctc_sales)
diff = avg_sales-avg_hr

print(avg_hr)
print(avg_sales)
print("difference between hr and sales department's salary :",diff)
# Out:
# 125250
# 875275
# 37293.942
# 42293.942
# difference between hr and sales department's salary : 5000.0

# %% [markdown]
# # TASK 9

# %%
n = np.count_nonzero(np.where(ctc_sales>50000))
m = np.count_nonzero(np.where(ctc_sales<55000))

print(n)
print(m)
print("employees of more than 50000 and less than 55000 salary in sales department : ",m-n)
# Out:
# 97
# 499
# employees of more than 50000 and less than 55000 salary in sales department :  402

# %% [markdown]
# # TASK 10

# %%
from numpy import genfromtxt

npb = genfromtxt('DS1_C4_S1_Numpy_PracticeBrief.csv',delimiter=',',skip_header=True)
print(npb)
age = npb[:,-1]
npb.shape
# Out:
# [[ 1. 22.]
#  [ 2. 27.]
#  [ 3. 31.]
#  [ 4. 29.]
#  [ 5. 27.]
#  [ 6. 26.]
#  [ 7. 27.]
#  [ 8. 23.]
#  [ 9. 27.]
#  [10. 32.]
#  [11. 28.]
#  [12. 27.]
#  [13. 22.]
#  [14. 27.]
#  [15. 35.]
#  [16. 33.]
#  [17. 28.]
#  [18. 22.]
#  [19. 25.]
#  [20. 27.]
#  [21. 37.]
#  [22. 27.]
#  [23. 24.]
#  [24. 27.]
#  [25. 28.]
#  [26. 26.]
#  [27. 27.]
#  [28. 27.]
#  [29. 29.]
#  [30. 49.]
#  [31. 26.]
#  [32. 32.]
#  [33. 26.]
#  [34. 24.]
#  [35. 24.]
#  [36. 23.]
#  [37. 28.]
#  [38. 28.]
#  [39. 22.]
#  [40. 26.]
#  [41. 32.]
#  [42. 35.]
#  [43. 33.]
#  [44. 31.]
#  [45. 30.]
#  [46. 36.]
#  [47. 22.]
#  [48. 23.]
#  [49. 32.]
#  [50. 34.]]
# (50, 2)

# %% [markdown]
# # TASK 11

# %%
print(age)
c = np.where(age>25)
print('people above 25 years are : \n' ,npb[c])
# Out:
# [22. 27. 31. 29. 27. 26. 27. 23. 27. 32. 28. 27. 22. 27. 35. 33. 28. 22.
#  25. 27. 37. 27. 24. 27. 28. 26. 27. 27. 29. 49. 26. 32. 26. 24. 24. 23.
#  28. 28. 22. 26. 32. 35. 33. 31. 30. 36. 22. 23. 32. 34.]
# people above 25 years are :
#  [[ 2. 27.]
#  [ 3. 31.]
#  [ 4. 29.]
#  [ 5. 27.]
#  [ 6. 26.]
#  [ 7. 27.]
#  [ 9. 27.]
#  [10. 32.]
#  [11. 28.]
#  [12. 27.]
#  [14. 27.]
#  [15. 35.]
#  [16. 33.]
#  [17. 28.]
#  [20. 27.]
#  [21. 37.]
#  [22. 27.]
#  [24. 27.]
#  [25. 28.]
#  [26. 26.]
#  [27. 27.]
#  [28. 27.]
#  [29. 29.]
#  [30. 49.]
#  [31. 26.]
#  [32. 32.]
#  [33. 26.]
#  [37. 28.]
#  [38. 28.]
#  [40. 26.]
#  [41. 32.]
#  [42. 35.]
#  [43. 33.]
#  [44. 31.]
#  [45. 30.]
#  [46. 36.]
#  [49. 32.]
#  [50. 34.]]

# %% [markdown]
# # TASK 12

# %%
print(age)

d=np.where((age>30) & (age<35))
print(d)

print("people above 30 and below 35 years are : \n \n" ,npb[d])
# Out:
# [22. 27. 31. 29. 27. 26. 27. 23. 27. 32. 28. 27. 22. 27. 35. 33. 28. 22.
#  25. 27. 37. 27. 24. 27. 28. 26. 27. 27. 29. 49. 26. 32. 26. 24. 24. 23.
#  28. 28. 22. 26. 32. 35. 33. 31. 30. 36. 22. 23. 32. 34.]
# (array([ 2,  9, 15, 31, 40, 42, 43, 48, 49], dtype=int64),)
# people above 30 and below 35 years are :
#
#  [[ 3. 31.]
#  [10. 32.]
#  [16. 33.]
#  [32. 32.]
#  [41. 32.]
#  [43. 33.]
#  [44. 31.]
#  [49. 32.]
#  [50. 34.]]
